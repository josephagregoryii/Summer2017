# %%
import csv
import string
import pandas as pd


#Open the csv file and convert it to a list of dictionaries
def openfileStopWords(filename):
    with open(filename, encoding = 'ascii', errors = 'ignore') as csvfile:
        reader = csv.reader(csvfile)
        contents = [i for row in reader for i in row if i != '']
        csvfile.close()
    return contents

def openfile(filename):
    """
    important indexes for tables:
        "id" = 0
        "postURL" = 1
        "message" = 2
        "cta" = 4
        "intents" = 3
    """
    final = []
    with open(filename, encoding = 'ascii', errors = 'ignore') as csvfile:
        reader = csv.reader(csvfile)
        contents = [row for row in reader]
        csvfile.close()
    tables = contents[0]
    for i in contents[1:]:
        temp_dict = {"id": None, "postURL": None, "message": None, "cta": None, "intent": None }
        temp = i
        temp_dict["id"] = temp[0]
        temp_dict["postURL"] = temp[1]
        temp_dict["message"] = temp[2]
        temp_dict["cta"] = temp[4]
        temp_dict["intent"] = temp[3]
        final.append(temp_dict)
    return final

#stopWords = ["to", "a", "the", "is"]

#Filter the list of the posts depending on the user-inputed intent number
def selectIntent(list_of_dictionary, intent):
    list = [dict for dict in list_of_dictionary if dict['intent'] == intent]
    return list

#Take one message and strip, then make a list of dictionaries of words and its counts within that message

def toWordDict(rawMessage, stopWords):                                    #original
    word_dict = []
    added = False
    message = str.lower(rawMessage)
    translator = str.maketrans('', '', string.punctuation)
    message = message.translate(translator)

    for word in message.split():
        for i in word_dict:
            if i['word'] == word:
                if word in stopWords:
                    added = True
                else:
                    i['score'] = i['score'] + 1
                    added = True
        if added == False and (word in stopWords) == False:
            word_dict.append({'word': word, 'score': 1})
        else:
            added = False
    return word_dict
                                      

#Take a wholeList of words with scores and combine it with one word dictionary extracted from one message
def combine(wholeList, wordDict):
    for i in wordDict:
        dict = list(filter(lambda x: x['word'] == i['word'], wholeList))
        if dict == []:
            wholeList.append({'word': i['word'], 'score': i['score']})
        else:
            foundDict = dict[0]
            foundDict['score'] = foundDict['score'] + i['score']
    return wholeList

test_dict = [{'message': "hi my name! is ellen?", 'intent': "1"},
 {'message': "what is your Name!", 'intent': "1"},
 {'message': "this has a different intent", 'intent': "2"}]

intent_number = ["1", "2", "3", "4"]

def combinecsv():
    to_merge = ['word_counts_intent{}.csv'.format(i+1) for i in range(4)]
    dfs = []
    for filename in to_merge:
        # read the csv, making sure the first two columns are str
        df = pd.read_csv(filename, header=None, converters={0: str, 1: str})
        # throw away all but the first two columns
        df = df.ix[:,:1]
        # change the column names so they won't collide during concatenation
        df.columns = [filename + str(cname) for cname in df.columns]
        dfs.append(df)

    # concatenate them horizontally
    merged = pd.concat(dfs,axis=1)
    # write it out
    merged.to_csv("word_counts_intent_MERGED.csv", header=None, index=None)


def main():
    list_of_dictionary = openfile('data_intent_bucketing.csv')
    stopWords = openfileStopWords('stopWords.csv')
    for number in intent_number:
        list_of_selected = selectIntent(list_of_dictionary, number)
        
        #extract a list of messages from a list of posts
        list_of_messages = [i['message'] for i in list_of_selected]
        list_of_words = []#List of dictionary [{'word': "Donate", 'score': "13"}, ...]

        #extract a list of words/score from a list of messages
        for j in list_of_messages:
            wordDict = toWordDict(j, stopWords)
            list_of_words = combine(list_of_words, wordDict)

        rankedList = sorted(list_of_words, key = (lambda p: -p['score']))

        #export it as a .csv file
        print(rankedList)
        keys = rankedList[0].keys()

        fileName = "word_counts_intent" + number + ".csv"
        with open(fileName, 'w') as output_file:
            dict_writer = csv.DictWriter(output_file, keys)
            dict_writer.writeheader()
            dict_writer.writerows(rankedList)
        

if __name__ == '__main__':
    main()
    combinecsv()
# Out:
# [{'score': 132, 'word': 'i'}, {'score': 121, 'word': 'we'}, {'score': 106, 'word': 'you'}, {'score': 106, 'word': 'in'}, {'score': 104, 'word': 'this'}, {'score': 102, 'word': 'kickstarter'}, {'score': 101, 'word': 'with'}, {'score': 100, 'word': 'for'}, {'score': 75, 'word': 'our'}, {'score': 66, 'word': 'out'}, {'score': 61, 'word': 'rt'}, {'score': 48, 'word': 'about'}, {'score': 48, 'word': 'live'}, {'score': 45, 'word': 'your'}, {'score': 45, 'word': 'have'}, {'score': 41, 'word': 'clonsters'}, {'score': 40, 'word': 'my'}, {'score': 36, 'word': 'new'}, {'score': 36, 'word': 'dream'}, {'score': 35, 'word': 'now'}, {'score': 35, 'word': 'will'}, {'score': 34, 'word': 'time'}, {'score': 33, 'word': 'book'}, {'score': 32, 'word': 'from'}, {'score': 32, 'word': 'make'}, {'score': 32, 'word': 'day'}, {'score': 31, 'word': 'all'}, {'score': 31, 'word': 'more'}, {'score': 30, 'word': 'us'}, {'score': 29, 'word': 'get'}, {'score': 29, 'word': 'were'}, {'score': 29, 'word': 'me'}, {'score': 29, 'word': 'loud'}, {'score': 27, 'word': 'one'}, {'score': 25, 'word': 'help'}, {'score': 25, 'word': 'u2'}, {'score': 24, 'word': 'love'}, {'score': 23, 'word': 'do'}, {'score': 22, 'word': 'no'}, {'score': 21, 'word': 'here'}, {'score': 21, 'word': 'them'}, {'score': 21, 'word': 'need'}, {'score': 20, 'word': 'amp'}, {'score': 20, 'word': 'great'}, {'score': 20, 'word': 'campaign'}, {'score': 19, 'word': 'via'}, {'score': 19, 'word': 'there'}, {'score': 19, 'word': 'want'}, {'score': 19, 'word': 'world'}, {'score': 19, 'word': 'film'}, {'score': 18, 'word': 'story'}, {'score': 18, 'word': 'made'}, {'score': 17, 'word': 'they'}, {'score': 17, 'word': 'see'}, {'score': 17, 'word': 'going'}, {'score': 17, 'word': 'well'}, {'score': 17, 'word': 'has'}, {'score': 17, 'word': 'who'}, {'score': 17, 'word': 'novel'}, {'score': 17, 'word': 'amy'}, {'score': 16, 'word': 'adventure'}, {'score': 15, 'word': 'check'}, {'score': 15, 'word': 'some'}, {'score': 15, 'word': 'had'}, {'score': 15, 'word': 'he'}, {'score': 15, 'word': 'know'}, {'score': 15, 'word': 'graphic'}, {'score': 15, 'word': 'pledge'}, {'score': 15, 'word': 'nnhttpkckst2qm1pwl'}, {'score': 14, 'word': 'im'}, {'score': 14, 'word': 'dont'}, {'score': 14, 'word': 'up'}, {'score': 14, 'word': 'look'}, {'score': 14, 'word': 'first'}, {'score': 14, 'word': 'comic'}, {'score': 14, 'word': 'go'}, {'score': 14, 'word': 'music'}, {'score': 14, 'word': 'pm'}, {'score': 13, 'word': 'next'}, {'score': 13, 'word': 'wallet'}, {'score': 13, 'word': 'touch'}, {'score': 13, 'word': '3dprinting'}, {'score': 13, 'word': 'been'}, {'score': 13, 'word': 'please'}, {'score': 13, 'word': 'come'}, {'score': 13, 'word': 'fun'}, {'score': 13, 'word': 'real'}, {'score': 13, 'word': 'allages'}, {'score': 13, 'word': 'dotsloops'}, {'score': 13, 'word': 'fans'}, {'score': 12, 'word': 'days'}, {'score': 12, 'word': 'still'}, {'score': 12, 'word': 'hours'}, {'score': 12, 'word': 'best'}, {'score': 12, 'word': 'would'}, {'score': 12, 'word': 'also'}, {'score': 12, 'word': 'seen'}, {'score': 12, 'word': 'art'}, {'score': 12, 'word': 'then'}, {'score': 12, 'word': 'other'}, {'score': 12, 'word': 'today'}, {'score': 12, 'word': 'meets'}, {'score': 12, 'word': 'aaahh'}, {'score': 12, 'word': 'awesome'}, {'score': 12, 'word': 'back'}, {'score': 11, 'word': 'astrobox'}, {'score': 11, 'word': 'years'}, {'score': 11, 'word': 'ive'}, {'score': 11, 'word': 'set'}, {'score': 11, 'word': 'too'}, {'score': 11, 'word': 'which'}, {'score': 11, 'word': 'monsters'}, {'score': 11, 'word': 'vanessa'}, {'score': 11, 'word': '2'}, {'score': 11, 'word': 'nomercygame'}, {'score': 10, 'word': 'share'}, {'score': 10, 'word': '20'}, {'score': 10, 'word': 'link'}, {'score': 10, 'word': '3d'}, {'score': 10, 'word': 'year'}, {'score': 10, 'word': 'most'}, {'score': 10, 'word': 'support'}, {'score': 10, 'word': '5'}, {'score': 10, 'word': 'cant'}, {'score': 10, 'word': 'beautiful'}, {'score': 10, 'word': 'life'}, {'score': 10, 'word': 'young'}, {'scor ...
# [{'score': 216, 'word': 'you'}, {'score': 115, 'word': 'thank'}, {'score': 107, 'word': 'kickstarter'}, {'score': 103, 'word': 'thanks'}, {'score': 86, 'word': 'we'}, {'score': 80, 'word': 'for'}, {'score': 66, 'word': 'much'}, {'score': 57, 'word': 'this'}, {'score': 54, 'word': 'in'}, {'score': 49, 'word': 'our'}, {'score': 48, 'word': 'i'}, {'score': 47, 'word': 'us'}, {'score': 39, 'word': 'u2'}, {'score': 38, 'word': 'have'}, {'score': 37, 'word': 'today'}, {'score': 37, 'word': 'your'}, {'score': 37, 'word': 'all'}, {'score': 33, 'word': 'with'}, {'score': 30, 'word': 'days'}, {'score': 30, 'word': 'everyone'}, {'score': 28, 'word': 'out'}, {'score': 28, 'word': 'left'}, {'score': 28, 'word': 'has'}, {'score': 27, 'word': 'now'}, {'score': 26, 'word': 'who'}, {'score': 25, 'word': 'do'}, {'score': 24, 'word': 'about'}, {'score': 21, 'word': 'will'}, {'score': 20, 'word': 'support'}, {'score': 20, 'word': 'day'}, {'score': 20, 'word': 'fundclonsters'}, {'score': 20, 'word': 'dream'}, {'score': 20, 'word': 'httpbitlyclonsters'}, {'score': 19, 'word': 'make'}, {'score': 19, 'word': 'up'}, {'score': 19, 'word': 'live'}, {'score': 19, 'word': 'been'}, {'score': 19, 'word': 'campaign'}, {'score': 19, 'word': 'film'}, {'score': 19, 'word': 'loud'}, {'score': 18, 'word': 'know'}, {'score': 18, 'word': 'come'}, {'score': 16, 'word': 'going'}, {'score': 16, 'word': 'want'}, {'score': 16, 'word': 'me'}, {'score': 16, 'word': 'were'}, {'score': 15, 'word': 'time'}, {'score': 15, 'word': 'youre'}, {'score': 15, 'word': 'clonsters'}, {'score': 15, 'word': 'help'}, {'score': 15, 'word': 'join'}, {'score': 15, 'word': 'fans'}, {'score': 14, 'word': 'get'}, {'score': 14, 'word': 'fan'}, {'score': 14, 'word': 'pledged'}, {'score': 13, 'word': 'one'}, {'score': 13, 'word': 'see'}, {'score': 13, 'word': 'please'}, {'score': 13, 'word': 'goal'}, {'score': 12, 'word': 'funded'}, {'score': 12, 'word': 'shared'}, {'score': 12, 'word': 'some'}, {'score': 11, 'word': 'love'}, {'score': 11, 'word': 'go'}, {'score': 10, 'word': 'project'}, {'score': 10, 'word': 'way'}, {'score': 10, 'word': 'more'}, {'score': 10, 'word': 'from'}, {'score': 10, 'word': 'keep'}, {'score': 10, 'word': 'band'}, {'score': 9, 'word': 'sure'}, {'score': 9, 'word': 'well'}, {'score': 9, 'word': 'any'}, {'score': 9, 'word': 'share'}, {'score': 9, 'word': 'pledge'}, {'score': 9, 'word': 'backing'}, {'score': 9, 'word': 'lets'}, {'score': 9, 'word': '6'}, {'score': 9, 'word': 'pm'}, {'score': 9, 'word': 'there'}, {'score': 8, 'word': 'rt'}, {'score': 8, 'word': '1'}, {'score': 8, 'word': 'no'}, {'score': 8, 'word': 'ha'}, {'score': 8, 'word': 'then'}, {'score': 8, 'word': 'great'}, {'score': 8, 'word': 'community'}, {'score': 8, 'word': 'need'}, {'score': 8, 'word': 'hours'}, {'score': 8, 'word': 'world'}, {'score': 8, 'word': 'lt3'}, {'score': 8, 'word': 'dreams'}, {'score': 8, 'word': 'over'}, {'score': 8, 'word': 'every'}, {'score': 8, 'word': 'wwwdreamoutloudfilmcom'}, {'score': 8, 'word': 'dreamoutloud'}, {'score': 8, 'word': 'hamster'}, {'score': 7, 'word': 'dont'}, {'score': 7, 'word': 'good'}, {'score': 7, 'word': 'say'}, {'score': 7, 'word': 'weve'}, {'score': 7, 'word': 'amp'}, {'score': 7, 'word': 'getting'}, {'score': 7, 'word': 'many'}, {'score': 7, 'word': 'wow'}, {'score': 7, 'word': 'means'}, {'score': 7, 'word': '7'}, {'score': 7, 'word': '100'}, {'score': 7, 'word': 'closer'}, {'score': 7, 'word': 'right'}, {'score': 7, 'word': '12'}, {'score': 7, 'word': 'music'}, {'score': 7, 'word': 'story'}, {'score': 7, 'word': 'february'}, {'score': 6, 'word': 'book'}, {'score': 6, 'word': 'tell'}, {'score': 6, 'word': 'here'}, {'score': 6, 'word': 'really'}, {'score': 6, 'word': 'indeed'}, {'score': 6, 'word': 'their'}, {'score': 6, 'word': 'too'}, {'score': 6, 'word': 'feel'}, {'score': 6, 'word': 'long'}, {'score': 6, 'word': 'talk'}, {'score': 6, 'word': 'danleydon'}, {'score': 6, 'word': 'ill'}, {'score': 6, 'word': 'first'}, {'score': 6, 'word': 'done'}, {'score' ...
# [{'score': 119, 'word': 'rt'}, {'score': 71, 'word': 'kickstarter'}, {'score': 66, 'word': 'clonsters'}, {'score': 52, 'word': 'for'}, {'score': 47, 'word': 'out'}, {'score': 34, 'word': 'check'}, {'score': 32, 'word': 'you'}, {'score': 31, 'word': 'this'}, {'score': 31, 'word': 'allages'}, {'score': 28, 'word': 'patshand'}, {'score': 25, 'word': 'in'}, {'score': 25, 'word': 'our'}, {'score': 24, 'word': 'comic'}, {'score': 23, 'word': 'i'}, {'score': 21, 'word': 'shand'}, {'score': 20, 'word': 'new'}, {'score': 20, 'word': 'we'}, {'score': 19, 'word': 'book'}, {'score': 19, 'word': 'amy'}, {'score': 19, 'word': 'adventure'}, {'score': 17, 'word': 'your'}, {'score': 17, 'word': 'with'}, {'score': 17, 'word': 'amp'}, {'score': 16, 'word': 'my'}, {'score': 16, 'word': 'pat'}, {'score': 15, 'word': 'from'}, {'score': 14, 'word': 'thanks'}, {'score': 14, 'word': 'us'}, {'score': 14, 'word': 'were'}, {'score': 14, 'word': 'graphic'}, {'score': 14, 'word': 'novel'}, {'score': 13, 'word': 'give'}, {'score': 13, 'word': 'kids'}, {'score': 12, 'word': 'support'}, {'score': 12, 'word': 'get'}, {'score': 12, 'word': 'about'}, {'score': 11, 'word': 'up'}, {'score': 11, 'word': 'all'}, {'score': 10, 'word': 'some'}, {'score': 10, 'word': 'hey'}, {'score': 10, 'word': 'backed'}, {'score': 10, 'word': 'game'}, {'score': 10, 'word': 'multivarious'}, {'score': 9, 'word': 'wallet'}, {'score': 9, 'word': 'love'}, {'score': 9, 'word': 'project'}, {'score': 9, 'word': 'too'}, {'score': 9, 'word': 'sheaserrano'}, {'score': 9, 'word': 'bedtime'}, {'score': 9, 'word': 'better'}, {'score': 9, 'word': 'back'}, {'score': 8, 'word': 'have'}, {'score': 8, 'word': 'help'}, {'score': 8, 'word': 'making'}, {'score': 8, 'word': 'im'}, {'score': 8, 'word': 'trying'}, {'score': 8, 'word': 'vanessa'}, {'score': 8, 'word': 'cardinali'}, {'score': 7, 'word': 'link'}, {'score': 7, 'word': 'httpst'}, {'score': 7, 'word': 'reading'}, {'score': 7, 'word': 'their'}, {'score': 7, 'word': 'granfors'}, {'score': 6, 'word': 'cool'}, {'score': 6, 'word': 'apex'}, {'score': 6, 'word': 'now'}, {'score': 6, 'word': 'think'}, {'score': 6, 'word': 'one'}, {'score': 6, 'word': 'news'}, {'score': 6, 'word': 'friends'}, {'score': 6, 'word': 'httpstcofxwejgi7ud'}, {'score': 6, 'word': 'material'}, {'score': 6, 'word': 'ericaschultz42'}, {'score': 6, 'word': 'no'}, {'score': 6, 'word': 'httpstco'}, {'score': 6, 'word': 'ages'}, {'score': 5, 'word': 'themstrmnd'}, {'score': 5, 'word': 'good'}, {'score': 5, 'word': 'little'}, {'score': 5, 'word': 'make'}, {'score': 5, 'word': 'piece'}, {'score': 5, 'word': 'goal'}, {'score': 5, 'word': 'hours'}, {'score': 5, 'word': 'press'}, {'score': 5, 'word': 'live'}, {'score': 5, 'word': 'page'}, {'score': 5, 'word': 'basketball'}, {'score': 5, 'word': 'thank'}, {'score': 5, 'word': 'there'}, {'score': 5, 'word': 'fun'}, {'score': 5, 'word': 'time'}, {'score': 5, 'word': 'please'}, {'score': 5, 'word': 'art'}, {'score': 5, 'word': 'gyrating'}, {'score': 5, 'word': 'hamsters'}, {'score': 4, 'word': 'great'}, {'score': 4, 'word': 'ht'}, {'score': 4, 'word': 'should'}, {'score': 4, 'word': 'astroprint3d'}, {'score': 4, 'word': 'astrobox'}, {'score': 4, 'word': 'way'}, {'score': 4, 'word': 'touch'}, {'score': 4, 'word': '3'}, {'score': 4, 'word': 'before'}, {'score': 4, 'word': 'httpstcohgz69ipknd'}, {'score': 4, 'word': 'come'}, {'score': 4, 'word': 'childrens'}, {'score': 4, 'word': 'here'}, {'score': 4, 'word': 'did'}, {'score': 4, 'word': 'sure'}, {'score': 4, 'word': 'parents'}, {'score': 4, 'word': 'much'}, {'score': 4, 'word': 'write'}, {'score': 4, 'word': 'people'}, {'score': 4, 'word': 'every'}, {'score': 4, 'word': 'doesnt'}, {'score': 4, 'word': 'could'}, {'score': 4, 'word': 'will'}, {'score': 4, 'word': 'continuityent'}, {'score': 4, 'word': 'me'}, {'score': 4, 'word': 'https'}, {'score': 4, 'word': 'epanel'}, {'score': 4, 'word': 'comicfrontline'}, {'score': 4, 'word': 'has'}, {'score': 4, 'word': 'meets'}, {'score': 4, 'word': 'free'}, ...
# [{'score': 130, 'word': 'we'}, {'score': 120, 'word': 'kickstarter'}, {'score': 105, 'word': 'you'}, {'score': 101, 'word': 'our'}, {'score': 93, 'word': 'for'}, {'score': 93, 'word': 'get'}, {'score': 90, 'word': 'in'}, {'score': 73, 'word': 'clonsters'}, {'score': 68, 'word': 'left'}, {'score': 66, 'word': 'this'}, {'score': 64, 'word': 'days'}, {'score': 61, 'word': 'your'}, {'score': 60, 'word': 'will'}, {'score': 54, 'word': 'now'}, {'score': 51, 'word': 'pledge'}, {'score': 51, 'word': 'have'}, {'score': 49, 'word': 'us'}, {'score': 48, 'word': 'today'}, {'score': 45, 'word': 'with'}, {'score': 41, 'word': 'out'}, {'score': 41, 'word': 'free'}, {'score': 41, 'word': 'help'}, {'score': 41, 'word': 'all'}, {'score': 38, 'word': 'were'}, {'score': 37, 'word': 'i'}, {'score': 36, 'word': 'hours'}, {'score': 35, 'word': 'day'}, {'score': 32, 'word': 'only'}, {'score': 31, 'word': 'make'}, {'score': 30, 'word': 'goal'}, {'score': 28, 'word': 'go'}, {'score': 28, 'word': 'fundclonsters'}, {'score': 27, 'word': 'do'}, {'score': 27, 'word': 'campaign'}, {'score': 27, 'word': 'dream'}, {'score': 26, 'word': 'raise'}, {'score': 26, 'word': 'who'}, {'score': 25, 'word': 'lets'}, {'score': 25, 'word': 'loud'}, {'score': 24, 'word': 'everyone'}, {'score': 23, 'word': 'new'}, {'score': 22, 'word': 'final'}, {'score': 22, 'word': 'going'}, {'score': 22, 'word': 'art'}, {'score': 21, 'word': 'commission'}, {'score': 21, 'word': 'has'}, {'score': 20, 'word': 'book'}, {'score': 20, 'word': 'print'}, {'score': 20, 'word': 'over'}, {'score': 19, 'word': 'from'}, {'score': 19, 'word': 'backers'}, {'score': 19, 'word': 'every'}, {'score': 18, 'word': 'more'}, {'score': 18, 'word': 'awesome'}, {'score': 18, 'word': 'link'}, {'score': 18, 'word': 'before'}, {'score': 18, 'word': 'amp'}, {'score': 17, 'word': 'two'}, {'score': 17, 'word': 'one'}, {'score': 17, 'word': 'hit'}, {'score': 17, 'word': 'been'}, {'score': 17, 'word': 'pledges'}, {'score': 17, 'word': 'support'}, {'score': 16, 'word': 'reward'}, {'score': 16, 'word': 'last'}, {'score': 16, 'word': 'there'}, {'score': 16, 'word': 'prints'}, {'score': 16, 'word': 'rewards'}, {'score': 16, 'word': 'graphic'}, {'score': 16, 'word': 'pledged'}, {'score': 16, 'word': 'need'}, {'score': 16, 'word': 'back'}, {'score': 15, 'word': 'still'}, {'score': 15, 'word': 'up'}, {'score': 15, 'word': 'funded'}, {'score': 15, 'word': 'vampire'}, {'score': 15, 'word': 'emmy'}, {'score': 15, 'word': 'come'}, {'score': 15, 'word': 'please'}, {'score': 15, 'word': 'live'}, {'score': 15, 'word': 'u2'}, {'score': 14, 'word': 'time'}, {'score': 14, 'word': 'also'}, {'score': 14, 'word': 'first'}, {'score': 14, 'word': '100'}, {'score': 14, 'word': 'thanks'}, {'score': 14, 'word': 'artist'}, {'score': 14, 'word': '1'}, {'score': 14, 'word': 'some'}, {'score': 13, 'word': 'film'}, {'score': 13, 'word': 'wallet'}, {'score': 13, 'word': '20'}, {'score': 13, 'word': 'add'}, {'score': 13, 'word': 'added'}, {'score': 13, 'word': 'httpbitlyclonsters'}, {'score': 12, 'word': 'off'}, {'score': 12, 'word': 'my'}, {'score': 12, 'word': 'coloring'}, {'score': 12, 'word': 'ny'}, {'score': 12, 'word': 'until'}, {'score': 12, 'word': 'youre'}, {'score': 12, 'word': 'novel'}, {'score': 12, 'word': 'level'}, {'score': 12, 'word': 'even'}, {'score': 12, 'word': '50'}, {'score': 12, 'word': 'weve'}, {'score': 12, 'word': 'dotsloops'}, {'score': 12, 'word': 'story'}, {'score': 12, 'word': 'fans'}, {'score': 11, 'word': 'them'}, {'score': 11, 'word': 'stretch'}, {'score': 11, 'word': 'announcing'}, {'score': 11, 'word': 'destiny'}, {'score': 11, 'word': 'manuel'}, {'score': 11, 'word': 'im'}, {'score': 11, 'word': 'copy'}, {'score': 11, 'word': 'shared'}, {'score': 11, 'word': 'exclusive'}, {'score': 11, 'word': 'no'}, {'score': 10, 'word': 'apex'}, {'score': 10, 'word': 'while'}, {'score': 10, 'word': 'keep'}, {'score': 10, 'word': 'three'}, {'score': 10, 'word': '3'}, {'score': 10, 'word': 'villain'}, {'score': 10, 'word': 'thank'}, ...
