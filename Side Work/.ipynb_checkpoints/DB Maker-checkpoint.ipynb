# %%
import sqlite3
import csv
from sqlite3 import Error
from sqlite3 import connect
 

def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)
 
    return None
        
def get_data(database):

    with open('data_with_imgurl2.csv', errors='ignore') as csvfile:
        reader = csv.reader(csvfile)
        contents = [row for row in reader]
    print(len(contents))  
    
    for i in range(1, len(contents)):
        add_content(database, contents[i])
        print('adding ' + str(i))

def create_table(conn, table_query):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        c = conn.cursor()
        c.execute(table_query)
    except Error as e:
        print(e)
        
def add_content(database, lst):
    curr = database.cursor()
    query = 'INSERT INTO posts( \
                post_id, \
                handle, \
                postDate, \
                postType, \
                gen_postType,\
                postUrl, \
                platform, \
                messge, \
                twitter_comment, \
                twitter_retweet, \
                relevant_prediction, \
                cta_prediction, \
                sell_prediction, \
                intent_prediction, \
                comments, \
                shares, \
                likes, \
                views, \
                CampaignId, \
                campaign_name, \
                campaign_starteDate, \
                campaign_endDate, \
                project_currency, \
                project_staffPick, \
                sub_category, \
                CategoryNames, \
                CategoryNumbers, \
                project_url, \
                project_backerCount, \
                project_goal, \
                project_pledgeAmount, \
                Succeeded, \
                imageUrl) VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)'
    curr.execute(query,lst[1:])
    return curr.lastrowid
    
    
def main():
    database = 'database.db'
    
    table_query = 'CREATE TABLE \
                IF NOT EXISTS posts(post_id text NOT NULL, \
                handle text NOT NULL, \
                postDate text NOT NULL, \
                postType text NOT NULL, \
                gen_postType text NOT NULL,\
                postUrl text NOT NULL, \
                platform text NOT NULL, \
                messge text, \
                twitter_comment text NOT NULL, \
                twitter_retweet text NOT NULL, \
                relevant_prediction text NOT NULL, \
                cta_prediction text NOT NULL, \
                sell_prediction text NOT NULL, \
                intent_prediction text NOT NULL, \
                comments text NOT NULL, \
                shares text NOT NULL, \
                likes text NOT NULL, \
                views text NOT NULL, \
                CampaignId text NOT NULL, \
                campaign_name text NOT NULL, \
                campaign_starteDate text NOT NULL, \
                campaign_endDate text NOT NULL, \
                project_currency text NOT NULL, \
                project_staffPick text NOT NULL, \
                sub_category text NOT NULL, \
                CategoryNames text NOT NULL, \
                CategoryNumbers text NOT NULL, \
                project_url text NOT NULL, \
                project_backerCount text NOT NULL, \
                project_goal text NOT NULL, \
                project_pledgeAmount text NOT NULL, \
                Succeeded text NOT NULL, \
                imageUrl text NOT NULL \
               );'

    conn = create_connection(database)
    if conn is not None:
        create_table(conn, table_query)#create projects table
    else:
        print("Error")

if __name__ == '__main__':
    main()
    conn = create_connection(database)
    create_table(conn)
    get_data(conn)
# Out:
# 2.6.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-cc26822c33ae> in <module>()
#      41     database = 'database.db'
#      42     conn = create_connection(database)
# ---> 43     create_table(conn)
#      44     get_data(conn)
#      45
#
# <ipython-input-6-cc26822c33ae> in create_table(database)
#      27
#      28 def create_table(database):
# ---> 29     conn = connect(database)
#      30     db = conn.cursor()
# ...
